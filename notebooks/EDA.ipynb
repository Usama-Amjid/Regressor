# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('data\gemstone.csv')
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.sample(8)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 149262  149262   1.00    Premium     H     VS2   59.3   60.0  6.56  6.50
# 108476  108476   0.70      Ideal     G     VS1   62.0   56.0  5.68  5.73
# 108818  108818   1.22    Premium     G     VS1   62.0   58.0  6.83  6.77
# 101735  101735   1.52  Very Good     G     VS1   63.1   59.0  7.26  7.32
# 47186    47186   0.55      Ideal     G    VVS2   62.9   57.0  5.25  5.22
# 81538    81538   0.41    Premium     D     SI2   62.3   59.0  4.78  4.74
# 3736      3736   0.36    Premium     E    VVS1   60.3   58.0  4.65  4.61
# 6916      6916   1.02    Premium     F     VS1   61.5   59.0  6.44  6.42
#
#            z  price
# 149262  3.87   4928
# 108476  3.54   3017
# 108818  4.22   8977
# 101735  4.60  13445
# 47186   3.29   1935
# 81538   2.97    851
# 3736    2.79   1068
# 6916    3.96   7197

# %%
df.carat.nunique()
# Out:
# 248

# %%
df.carat.describe()
# Out:
# count    193573.000000
# mean          0.790688
# std           0.462688
# min           0.200000
# 25%           0.400000
# 50%           0.700000
# 75%           1.030000
# max           3.500000
# Name: carat, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.array(sorted(df.carat.unique()))
# Out:
# array([0.2 , 0.21, 0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 ,
#        0.31, 0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38, 0.39, 0.4 , 0.41,
#        0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 , 0.51, 0.52,
#        0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63,
#        0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71, 0.72, 0.73, 0.74,
#        0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82, 0.83, 0.84, 0.85,
#        0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96,
#        0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03, 1.04, 1.05, 1.06, 1.07,
#        1.08, 1.09, 1.1 , 1.11, 1.12, 1.13, 1.14, 1.15, 1.16, 1.17, 1.18,
#        1.19, 1.2 , 1.21, 1.22, 1.23, 1.24, 1.25, 1.26, 1.27, 1.28, 1.29,
#        1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37, 1.38, 1.39, 1.4 ,
#        1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48, 1.49, 1.5 , 1.51,
#        1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59, 1.6 , 1.61, 1.62,
# ...

# %%
plt.style.use('fivethirtyeight')

# %%
sns.histplot(data=df,x='carat')
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
df.shape
# Out:
# (193573, 11)

# %%
sns.distplot(df.carat)
# Out:
# C:\Users\Usama\AppData\Local\Temp\ipykernel_21584\454831864.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.carat)
# <Axes: xlabel='carat', ylabel='Density'>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df,x='carat')
# Out:
# <Axes: xlabel='carat'>

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df.corr(numeric_only=1)['price']
# Out:
# id      -0.001392
# carat    0.943396
# depth    0.001880
# table    0.174915
# x        0.901004
# y        0.901033
# z        0.893037
# price    1.000000
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
df.drop(columns=['id'],inplace=True)

# %%
df.sample(5)
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 65485    1.05  Very Good     J     SI2   60.0   58.0  6.65  6.58  3.96   3933
# 178400   1.03    Premium     G     VS1   62.9   58.0  6.40  6.44  4.03   6742
# 150394   0.35      Ideal     F     VS2   61.9   55.0  4.49  4.51  2.79    746
# 111586   1.01       Good     E     SI1   63.4   60.0  6.32  6.27  4.00   5644
# 91471    1.20    Premium     H     VS2   63.0   58.0  6.70  6.63  4.20   5450

# %%
df.duplicated().sum()
# Out:
# 0

# %%
numerical_columns=df.select_dtypes([int,float]).columns

# %%
categorical_columns=df.select_dtypes('O').columns

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df.cut.value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df.groupby('cut')['price'].mean()
# Out:
# cut
# Fair         4810.503216
# Good         4191.474101
# Ideal        3396.186969
# Premium      4797.056482
# Very Good    4165.304344
# Name: price, dtype: float64

# %%
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}
clarity_map={'I1':1,'SI2':2,'SI1':3,'VVS2':4,'VVS1':5,'VVS2':6,'VVS1':7,'IF':8}
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}
# Out:
# {'Fair': 1, 'Good': 2, 'Very Good': 3, 'Premium': 4, 'Ideal': 5}

# %%
df.clarity.unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={'I1':1,'SI2':2,'SI1':3,'VVS2':4,'VVS1':5,'VVS2':6,'VVS1':7,'IF':8}
clarity_map
# Out:
# {'I1': 1, 'SI2': 2, 'SI1': 3, 'VVS2': 6, 'VVS1': 7, 'IF': 8}

# %%
df.color.unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}
color_map
# Out:
# {'D': 1, 'E': 2, 'F': 3, 'G': 4, 'H': 5, 'I': 6, 'J': 7}

# %%
df.color.replace(color_map)
# Out:
# 0         3
# 1         7
# 2         4
# 3         4
# 4         4
#          ..
# 193568    1
# 193569    4
# 193570    3
# 193571    1
# 193572    2
# Name: color, Length: 193573, dtype: int64

# %%
df.cut.replace(cut_map,inplace=True)

# %%
df.clarity.replace(clarity_map,inplace=True)

# %%
df.color.replace(color_map,inplace=True)
